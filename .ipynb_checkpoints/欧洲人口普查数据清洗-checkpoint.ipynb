# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import time

# %%
pop = pd.read_csv('european_cities.csv')
pop
# Out:
#      Rank        City            State Population Date of census/estimate
# 0       1   London[2]   United Kingdom  8,615,246                1-Jun-14
# 1       2      Berlin          Germany  3,437,916               31-May-14
# 2       3      Madrid            Spain  3,165,235                1-Jan-14
# 3       4        Rome            Italy  2,872,086               30-Sep-14
# 4       5       Paris           France  2,273,305                1-Jan-13
# ..    ...         ...              ...        ...                     ...
# 100   101        Bonn          Germany    309,869               31-Dec-12
# 101   102       Malmö           Sweden    309,105               31-Mar-13
# 102   103  Nottingham   United Kingdom    308,735               30-Jun-12
# 103   104    Katowice           Poland    308,269               30-Jun-12
# 104   105      Kaunas        Lithuania    306,888                1-Jan-13
#
# [105 rows x 5 columns]

# %%
pop.shape
# Out:
# (105, 5)

# %%
#查看基本信息
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     105 non-null    int64
#  1   City                     105 non-null    object
#  2   State                    105 non-null    object
#  3   Population               105 non-null    object
#  4   Date of census/estimate  105 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.2+ KB

# %%
#查看变量描述
pop.describe(include='all')
# Out:
#               Rank      City     State Population Date of census/estimate
# count   105.000000       105       105        105                     105
# unique         NaN       105        24        105                      29
# top            NaN  Budapest   Germany    898,095               30-Jun-12
# freq           NaN         1        19          1                      17
# mean     53.057143       NaN       NaN        NaN                     NaN
# std      30.428298       NaN       NaN        NaN                     NaN
# min       1.000000       NaN       NaN        NaN                     NaN
# 25%      27.000000       NaN       NaN        NaN                     NaN
# 50%      53.000000       NaN       NaN        NaN                     NaN
# 75%      79.000000       NaN       NaN        NaN                     NaN
# max     105.000000       NaN       NaN        NaN                     NaN

# %%
pop['State'].values
# Out:
# array([' United Kingdom', ' Germany', ' Spain', ' Italy', ' France',
#        ' Romania', ' Austria', ' Germany', ' Hungary', ' Poland',
#        ' Spain', ' Germany', ' Italy', ' Bulgaria', ' Czech Republic',
#        ' Belgium', ' United Kingdom', ' Germany', ' Italy', ' Sweden',
#        ' Italy', ' France', ' Netherlands', ' Croatia', ' Spain',
#        ' Poland', ' United Kingdom', ' Poland', ' Germany', ' Latvia',
#        ' Spain', ' Italy', ' Spain', ' Greece', ' Poland', ' Netherlands',
#        ' Finland', ' Germany', ' United Kingdom', ' Italy', ' Germany',
#        ' Germany', ' Germany', ' Spain', ' Denmark', ' United Kingdom',
#        ' Portugal', ' Poland', ' Germany', ' Lithuania', ' Germany',
#        ' Germany', ' Sweden', ' Ireland', ' United Kingdom', ' Germany',
#        ' Netherlands', ' United Kingdom', ' Belgium', ' United Kingdom',
#        ' Germany', ' Germany', ' France', ' United Kingdom', ' Poland',
#        ' France', ' Spain', ' Estonia', ' United Kingdom',
#        'Slovakia Slovak Republic', ' Poland', ' Spain', ' Italy',
#        ' Spain', ' Italy', ' Czech Republic', ' Poland', ' Germany',
#        ' Spain', ' United Kingdom', ' Poland', ' France', ' Germany',
#        ' Bulgaria', ' Bulgaria', ' Spain', ' United Kingdom',
#        ' Netherlands', ' Spain', ' Germany', ' United Kingdom',
#        ' Denmark', ' Romania', ' United Kingdom', ' Italy', ' Greece',
#        ' United Kingdom', ' Romania', ' Italy', ' Spain', ' Germany',
#        ' Sweden', ' United Kingdom', ' Poland', ' Lithuania'],
#       dtype=object)

# %%
pop['NO_State'] = pop['State'].str.strip()
pop['NO_State'].values
# Out:
# array(['United Kingdom', 'Germany', 'Spain', 'Italy', 'France', 'Romania',
#        'Austria', 'Germany', 'Hungary', 'Poland', 'Spain', 'Germany',
#        'Italy', 'Bulgaria', 'Czech Republic', 'Belgium', 'United Kingdom',
#        'Germany', 'Italy', 'Sweden', 'Italy', 'France', 'Netherlands',
#        'Croatia', 'Spain', 'Poland', 'United Kingdom', 'Poland',
#        'Germany', 'Latvia', 'Spain', 'Italy', 'Spain', 'Greece', 'Poland',
#        'Netherlands', 'Finland', 'Germany', 'United Kingdom', 'Italy',
#        'Germany', 'Germany', 'Germany', 'Spain', 'Denmark',
#        'United Kingdom', 'Portugal', 'Poland', 'Germany', 'Lithuania',
#        'Germany', 'Germany', 'Sweden', 'Ireland', 'United Kingdom',
#        'Germany', 'Netherlands', 'United Kingdom', 'Belgium',
#        'United Kingdom', 'Germany', 'Germany', 'France', 'United Kingdom',
#        'Poland', 'France', 'Spain', 'Estonia', 'United Kingdom',
#        'Slovakia Slovak Republic', 'Poland', 'Spain', 'Italy', 'Spain',
#        'Italy', 'Czech Republic', 'Poland', 'Germany', 'Spain',
#        'United Kingdom', 'Poland', 'France', 'Germany', 'Bulgaria',
#        'Bulgaria', 'Spain', 'United Kingdom', 'Netherlands', 'Spain',
#        'Germany', 'United Kingdom', 'Denmark', 'Romania',
#        'United Kingdom', 'Italy', 'Greece', 'United Kingdom', 'Romania',
#        'Italy', 'Spain', 'Germany', 'Sweden', 'United Kingdom', 'Poland',
#        'Lithuania'], dtype=object)

# %%
pop.Population.str.replace(',','').astype(np.int64)
# Out:
# 0      8615246
# 1      3437916
# 2      3165235
# 3      2872086
# 4      2273305
#         ...
# 100     309869
# 101     309105
# 102     308735
# 103     308269
# 104     306888
# Name: Population, Length: 105, dtype: int64

# %%
pop['NO_population']=pop.Population.str.replace(',','').astype(np.int64)
pop.head()
# Out:
#    Rank       City           State Population Date of census/estimate  \
# 0     1  London[2]  United Kingdom  8,615,246                1-Jun-14
# 1     2     Berlin         Germany  3,437,916               31-May-14
# 2     3     Madrid           Spain  3,165,235                1-Jan-14
# 3     4       Rome           Italy  2,872,086               30-Sep-14
# 4     5      Paris          France  2,273,305                1-Jan-13
#
#    NO_population        NO_State
# 0        8615246  United Kingdom
# 1        3437916         Germany
# 2        3165235           Spain
# 3        2872086           Italy
# 4        2273305          France

# %%
pd.to_datetime(pop['Date of census/estimate'],dayfirst=True)
# Out:
# 0     2014-06-01
# 1     2014-05-31
# 2     2014-01-01
# 3     2014-09-30
# 4     2013-01-01
#          ...
# 100   2012-12-31
# 101   2013-03-31
# 102   2012-06-30
# 103   2012-06-30
# 104   2013-01-01
# Name: Date of census/estimate, Length: 105, dtype: datetime64[ns]

# %%
pop['NO_Date of census/estimate']= pd.to_datetime(pop['Date of census/estimate'],dayfirst=True)
pop
# Out:
#      Rank        City           State Population Date of census/estimate  \
# 0       1   London[2]  United Kingdom  8,615,246                1-Jun-14
# 1       2      Berlin         Germany  3,437,916               31-May-14
# 2       3      Madrid           Spain  3,165,235                1-Jan-14
# 3       4        Rome           Italy  2,872,086               30-Sep-14
# 4       5       Paris          France  2,273,305                1-Jan-13
# ..    ...         ...             ...        ...                     ...
# 100   101        Bonn         Germany    309,869               31-Dec-12
# 101   102       Malmö          Sweden    309,105               31-Mar-13
# 102   103  Nottingham  United Kingdom    308,735               30-Jun-12
# 103   104    Katowice          Poland    308,269               30-Jun-12
# 104   105      Kaunas       Lithuania    306,888                1-Jan-13
#
#      NO_population        NO_State NO_Date of census/estimate
# 0          8615246  United Kingdom                 2014-06-01
# 1          3437916         Germany                 2014-05-31
# 2          3165235           Spain                 2014-01-01
# 3          2872086           Italy                 2014-09-30
# 4          2273305          France                 2013-01-01
# ..             ...             ...                        ...
# 100         309869         Germany                 2012-12-31
# 101         309105          Sweden                 2013-03-31
# 102         308735  United Kingdom                 2012-06-30
# 103         308269          Poland                 2012-06-30
# 104         306888       Lithuania                 2013-01-01
#
# [105 rows x 8 columns]

# %%
pop.sort_values(by=['NO_Date of census/estimate','NO_population'],ascending = True) #sort_index
# Out:
#     Rank      City     State Population Date of census/estimate  \
# 81    82      Nice    France    343,304               31-Dec-10
# 65    66  Toulouse    France    441,802               31-Dec-10
# 62    63      Lyon    France    484,344               31-Dec-10
# 46    47    Lisbon  Portugal    547,631                1-Jan-11
# 23    24    Zagreb   Croatia    790,017               31-Mar-11
# ..   ...       ...       ...        ...                     ...
# 3      4      Rome     Italy  2,872,086               30-Sep-14
# 91    92    Aarhus   Denmark    326,676                1-Oct-14
# 13    14     Sofia  Bulgaria  1,291,895               14-Dec-14
# 6      7    Vienna   Austria  1,794,770                1-Jan-15
# 67    68   Tallinn   Estonia    434,810                1-Feb-15
#
#     NO_population  NO_State NO_Date of census/estimate
# 81         343304    France                 2010-12-31
# 65         441802    France                 2010-12-31
# 62         484344    France                 2010-12-31
# 46         547631  Portugal                 2011-01-01
# 23         790017   Croatia                 2011-03-31
# ..            ...       ...                        ...
# 3         2872086     Italy                 2014-09-30
# 91         326676   Denmark                 2014-10-01
# 13        1291895  Bulgaria                 2014-12-14
# 6         1794770   Austria                 2015-01-01
# 67         434810   Estonia                 2015-02-01
#
# [105 rows x 8 columns]

# %%
pop1=pop.set_index('NO_State','City').sort_index()
pop1
# Out:
#                 Rank          City           State Population  \
# NO_State
# Austria            7        Vienna         Austria  1,794,770
# Belgium           59       Antwerp         Belgium    510,610
# Belgium           16  Brussels[17]         Belgium  1,175,831
# Bulgaria          85         Varna        Bulgaria    335,819
# Bulgaria          84       Plovdiv        Bulgaria    341,041
# ...              ...           ...             ...        ...
# United Kingdom    64     Liverpool  United Kingdom    469,690
# United Kingdom    91     Wakefield  United Kingdom    327,627
# United Kingdom    69       Bristol  United Kingdom    432,451
# United Kingdom    55      Bradford  United Kingdom    524,619
# United Kingdom     1     London[2]  United Kingdom  8,615,246
#
#                Date of census/estimate  NO_population  \
# NO_State
# Austria                       1-Jan-15        1794770
# Belgium                       1-Jan-14         510610
# Belgium                       1-Jan-14        1175831
# Bulgaria                     31-Dec-13         335819
# Bulgaria                     31-Dec-13         341041
# ...                                ...            ...
# United Kingdom               30-Jun-12         469690
# United Kingdom               30-Jun-12         327627
# United Kingdom               30-Jun-12         432451
# United Kingdom               30-Jun-12         524619
# United Kingdom                1-Jun-14        8615246
#
#                NO_Date of census/estimate
# NO_State
# Austria                        2015-01-01
# Belgium                        2014-01-01
# Belgium                        2014-01-01
# Bulgaria                       2013-12-31
# Bulgaria                       2013-12-31
# ...                                   ...
# United Kingdom                 2012-06-30
# United Kingdom                 2012-06-30
# United Kingdom                 2012-06-30
# United Kingdom                 2012-06-30
# United Kingdom                 2014-06-01
#
# [105 rows x 7 columns]

# %%
pop1.reset_index(drop = True)
# Out:
#      Rank          City           State Population Date of census/estimate  \
# 0       7        Vienna         Austria  1,794,770                1-Jan-15
# 1      59       Antwerp         Belgium    510,610                1-Jan-14
# 2      16  Brussels[17]         Belgium  1,175,831                1-Jan-14
# 3      85         Varna        Bulgaria    335,819               31-Dec-13
# 4      84       Plovdiv        Bulgaria    341,041               31-Dec-13
# ..    ...           ...             ...        ...                     ...
# 100    64     Liverpool  United Kingdom    469,690               30-Jun-12
# 101    91     Wakefield  United Kingdom    327,627               30-Jun-12
# 102    69       Bristol  United Kingdom    432,451               30-Jun-12
# 103    55      Bradford  United Kingdom    524,619               30-Jun-12
# 104     1     London[2]  United Kingdom  8,615,246                1-Jun-14
#
#      NO_population NO_Date of census/estimate
# 0          1794770                 2015-01-01
# 1           510610                 2014-01-01
# 2          1175831                 2014-01-01
# 3           335819                 2013-12-31
# 4           341041                 2013-12-31
# ..             ...                        ...
# 100         469690                 2012-06-30
# 101         327627                 2012-06-30
# 102         432451                 2012-06-30
# 103         524619                 2012-06-30
# 104        8615246                 2014-06-01
#
# [105 rows x 7 columns]

# %%
pop.State.value_counts()
# Out:
# Germany                     19
# United Kingdom              16
# Spain                       13
# Poland                      10
# Italy                       10
# France                       5
# Netherlands                  4
# Bulgaria                     3
# Sweden                       3
# Romania                      3
# Czech Republic               2
# Lithuania                    2
# Belgium                      2
# Greece                       2
# Denmark                      2
# Finland                      1
# Hungary                      1
# Portugal                     1
# Croatia                      1
# Estonia                      1
# Slovakia Slovak Republic     1
# Latvia                       1
# Ireland                      1
# Austria                      1
# Name: State, dtype: int64

# %%
pop.State.value_counts(normalize= True)#计算频数
# Out:
# Germany                     0.180952
# United Kingdom              0.152381
# Spain                       0.123810
# Poland                      0.095238
# Italy                       0.095238
# France                      0.047619
# Netherlands                 0.038095
# Bulgaria                    0.028571
# Sweden                      0.028571
# Romania                     0.028571
# Czech Republic              0.019048
# Lithuania                   0.019048
# Belgium                     0.019048
# Greece                      0.019048
# Denmark                     0.019048
# Finland                     0.009524
# Hungary                     0.009524
# Portugal                    0.009524
# Croatia                     0.009524
# Estonia                     0.009524
# Slovakia Slovak Republic    0.009524
# Latvia                      0.009524
# Ireland                     0.009524
# Austria                     0.009524
# Name: State, dtype: float64

# %%
pop.groupby('State').sum().sort_values('NO_population',ascending=False).loc[:,['NO_population']]
# Out:
#                           NO_population
# State
# United Kingdom                 16011877
# Germany                        15119548
# Spain                          10041639
# Italy                           8764067
# Poland                          6267409
# France                          4395271
# Romania                         2527280
# Netherlands                     2271771
# Bulgaria                        1968755
# Austria                         1794770
# Sweden                          1747095
# Hungary                         1744665
# Belgium                         1686441
# Czech Republic                  1625107
# Greece                           986286
# Denmark                          886116
# Lithuania                        844040
# Croatia                          790017
# Latvia                           701185
# Finland                          605523
# Portugal                         547631
# Ireland                          527612
# Estonia                          434810
# Slovakia Slovak Republic         417389

# %%
#枢轴表
pop.pivot_table(index='NO_State',values='NO_population',
               aggfunc=np.sum).sort_values('NO_population',ascending=False)
# Out:
#                           NO_population
# NO_State
# United Kingdom                 16011877
# Germany                        15119548
# Spain                          10041639
# Italy                           8764067
# Poland                          6267409
# France                          4395271
# Romania                         2527280
# Netherlands                     2271771
# Bulgaria                        1968755
# Austria                         1794770
# Sweden                          1747095
# Hungary                         1744665
# Belgium                         1686441
# Czech Republic                  1625107
# Greece                           986286
# Denmark                          886116
# Lithuania                        844040
# Croatia                          790017
# Latvia                           701185
# Finland                          605523
# Portugal                         547631
# Ireland                          527612
# Estonia                          434810
# Slovakia Slovak Republic         417389

# %%
pop.pivot_table(values='NO_population',index=['NO_State','City'],
               columns='NO_Date of census/estimate',aggfunc=np.sum,fill_value=0)
# Out:
# NO_Date of census/estimate   2010-12-31  2011-01-01  2011-03-31  2011-04-10  \
# NO_State       City
# Austria        Vienna                 0           0           0           0
# Belgium        Antwerp                0           0           0           0
#                Brussels[17]           0           0           0           0
# Bulgaria       Plovdiv                0           0           0           0
#                Sofia                  0           0           0           0
# ...                                 ...         ...         ...         ...
# United Kingdom Manchester             0           0           0           0
#                Nottingham             0           0           0           0
#                Sheffield              0           0           0           0
#                Wakefield              0           0           0           0
#                Wirral                 0           0           0           0
#
# NO_Date of census/estimate   2011-05-24  2011-06-30  2011-10-20  2012-01-01  \
# NO_State       City
# Austria        Vienna                 0           0           0           0
# Belgium        Antwerp                0           0           0           0
#                Brussels[17]           0           0           0           0
# Bulgaria       Plovdiv                0           0           0           0
#                Sofia                  0           0           0           0
# ...                                 ...         ...         ...         ...
# United Kingdom Manchester             0           0           0           0
#                Nottingham             0           0           0           0
#                Sheffield              0           0           0           0
#                Wakefield              0           0           0           0
#                Wirral                 0           0           0           0
#
# NO_Date of census/estimate   2012-06-30  2012-12-31  ...  2014-03-31  \
# NO_State       City                                  ...
# Austria        Vienna                 0           0  ...           0
# Belgium        Antwerp                0           0  ...           0
#                Brussels[17]           0           0  ...           0
# Bulgaria       Plovdiv                0           0  ...           0
#                Sofia                  0           0  ...           0
# ...                                 ...         ...  ...         ...
# United Kingdom Manchester        510772           0  ...           0
#                Nottingham        308735           0  ...           0
#                Sheffield         557382           0  ...           0
#                Wakefield         327627           0  ...           0
#                Wirral            320229           0  ...           0
#
# NO_Date of census/estimate   2014-05-01  2014-05-31  2014-06-01  2014-07-31  \
# NO_State       City
# Austria        Vienna                 0           0           0           0
# Belgium        Antwerp                0           0           0           0
#                Brussels[17]           0           0           0           0
# Bulgaria       Plovdiv                0           0           0           0
#                Sofia                  0           0           0           0
# ...                                 ...         ...         ...         ...
# United Kingdom Manchester             0           0           0           0
#                Nottingham             0           0           0           0
#                Sheffield              0           0           0           0
#                Wakefield              0           0           0           0
#                Wirral                 0           0           0           0
#
# NO_Date of census/estimate   2014-09-30  2014-10-01  2014-12-14  2015-01-01  \
# NO_State       City
# Austria        Vienna                 0           0           0     1794770
# Belgium        Antwerp                0           0           0           0
#                Brussels[17]           0           0           0           0
# Bulgaria       Plovdiv                0           0           0           0
#                Sofia                  0           0     1291895           0
# ...                                 ...         ...         ...         ...
# United Kingdom Manchester             0           0           0           0
#                Nottingham             0           0           0           0
#                Sheffield              0           0           0           0
#                Wakefield              0           0           0           0
#                Wirral                 0           0           0           0
#
# NO_Date of census/estimate   2015-02-01
# NO_State       City
# Austria        Vienna                 0
# Belgium        Antwerp                0
#                Brussels[17]           0
# Bulgaria       Plovdiv                0
#                Sofia                  0
# ...                                 ...
# United Kingdom Manchester             0
#                Nottingham             0
#                Sheffield              0
#                Wakefield              0
#                Wirral                 0
#
# [105 rows x 29 columns]

# %%
fig, axes=plt.subplots(1,2,figsize=(12,8))
pop.NO_State.value_counts().plot(kind='barh',ax=axes[0])
axes[0].set_xlabel("number of cities")
pop1.NO_population.plot(kind='barh',ax=axes[1])
axes[1].set_xlabel("total population of state")
fig.tight_layout()
plt.show()
